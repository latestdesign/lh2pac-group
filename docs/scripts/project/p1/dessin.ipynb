# %% [markdown]
# Ce fichier permettra de dessiner quelques configuration d'avion.

# %%
#Dessiner l'avion 
#P3
from gemseo_oad_training.utils import AircraftConfiguration
from gemseo_oad_training.utils import draw_aircraft

configuration_1 = AircraftConfiguration(area=112.5423002728177, n_pax = 120,slst = 100000.0001693263, ar = 14.21688057592227 , name="Conf 1", color="b")
#draw_aircraft(configuration_1, title="Probleme 3 case 1")


configuration_2 = AircraftConfiguration(area=114.5665993753776, n_pax = 120,slst = 100121.550033296, ar = 9.40530768425236 , name="Conf 2", color="r")
#draw_aircraft(configuration_1, title="Probleme 3 case 2")

draw_aircraft(configuration_1, configuration_2, title="Comparison")

# %%
#Dessiner l'avion 
from gemseo_oad_training.utils import AircraftConfiguration
from gemseo_oad_training.utils import draw_aircraft

#P1 
configuration_1 = AircraftConfiguration(area=119.910, n_pax = 120,slst = 100000, ar = 9.386 , name="Conf 1", color="b")
#draw_aircraft(configuration_1, title="Probleme 3 case 1")


configuration_2 = AircraftConfiguration(area=109.204, n_pax = 120,slst = 100000, ar = 14.95 , name="Conf 2", color="r")
#draw_aircraft(configuration_1, title="Probleme 3 case 2")

draw_aircraft(configuration_1, configuration_2, title="Comparison")
